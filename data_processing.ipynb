# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ## Load data

# %%
TRAIN_CSV_PATH = "./data/train.csv"
data = pd.read_csv(TRAIN_CSV_PATH, index_col=False)
data.head(3)
# Out:
#                                            Statement  Label
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True

# %% [markdown]
# ## Clean digits, punctuation and symbols

# %%
def clean_text(x):
    text = ''.join([i for i in x if not i.isdigit()])
    text = re.sub("[!\?@^&.,/#$+%*:()'\"-]", ' ', text)
    return text

data['cleaned_statement'] = data.loc[:,'Statement'].apply(clean_text)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array  label_one_hot
# 0  [says, annies, list, political, group, support...              0
# 1  [when, decline, coal, start?, it, started, nat...              1
# 2  [hillary, clinton, agrees, john, mccain, votin...              1

# %% [markdown]
# ## Download NLTK Stopwords model

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LouisMM\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# ## Clean stopwords and lowercase

# %%
def clean_stopwords(x):
    text = x.split() 
    filtered_words = [word.lower() for word in text if word not in stopwords.words('english')]
    return filtered_words

data['text_array'] = data.loc[:,'cleaned_statement'].apply(clean_stopwords)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array  label_one_hot
# 0  [says, annies, list, political, group, support...              0
# 1  [when, decline, coal, start, it, started, natu...              1
# 2  [hillary, clinton, agrees, john, mccain, votin...              1

# %% [markdown]
# ## Create word embedding from data

# %%
word_to_ix = {}

for text_array in data['text_array']:
    for word in text_array:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)

word_to_ix
# Out:
# {'says': 0,
#  'annies': 1,
#  'list': 2,
#  'political': 3,
#  'group': 4,
#  'supports': 5,
#  'third': 6,
#  'trimester': 7,
#  'abortions': 8,
#  'demand': 9,
#  'when': 10,
#  'decline': 11,
#  'coal': 12,
#  'start': 13,
#  'it': 14,
#  'started': 15,
#  'natural': 16,
#  'gas': 17,
#  'took': 18,
#  'begin': 19,
#  'president': 20,
#  'george': 21,
#  'w': 22,
#  'bushs': 23,
#  'administration': 24,
#  'hillary': 25,
#  'clinton': 26,
#  'agrees': 27,
#  'john': 28,
#  'mccain': 29,
#  'voting': 30,
#  'give': 31,
#  'bush': 32,
#  'benefit': 33,
#  'doubt': 34,
#  'iran': 35,
#  'health': 36,
#  'care': 37,
#  'reform': 38,
#  'legislation': 39,
#  'likely': 40,
#  'mandate': 41,
#  'free': 42,
#  'sex': 43,
#  'change': 44,
#  'surgeries': 45,
#  'the': 46,
#  'economic': 47,
#  'turnaround': 48,
#  'end': 49,
#  'term': 50,
#  'chicago': 51,
#  'bears': 52,
#  'starting': 53,
#  'quarterbacks': 54,
#  'last': 55,
#  'years': 56,
#  'total': 57,
#  'number': 58,
#  'tenured': 59,
#  'uw': 60,
#  'faculty': 61,
#  'fired': 62,
#  'two': 63,
#  'decades': 64,
#  'jim': 65,
#  'dunnam': 66,
#  'lived': 67,
#  'district': 68,
#  'represents': 69,
#  'i': 70,
#  'person': 71,
#  'stage': 72,
#  'worked': 73,
#  'actively': 74,
#  'year': 75,
#  'passing': 76,
#  'along': 77,
#  'russ': 78,
#  'feingold': 79,
#  'toughest': 80,
#  'ethics': 81,
#  'since': 82,
#  'watergate': 83,
#  'however': 84,
#  'million': 85,
#  'oregon': 86,
#  'lottery': 87,
#  'funds': 88,
#  'port': 89,
#  'newport': 90,
#  'eventually': 91,
#  'land': 92,
#  'new': 93,
#  'noaa': 94,
#  'marine': 95,
#  'operations': 96,
#  'center': 97,
#  'pacific': 98,
#  'gop': 99,
#  'primary': 100,
#  'opponents': 101,
#  'glenn': 102,
#  'grothman': 103,
#  'joe': 104,
#  'leibham': 105,
#  'cast': 106,
#  'compromise': 107,
#  'vote': 108,
#  'cost': 109,
#  'higher': 110,
#  'electricity': 111,
#  'costs': 112,
#  'for': 113,
#  'first': 114,
#  'time': 115,
#  'history': 116,
#  'share': 117,
#  'national': 118,
#  'popular': 119,
#  'margin': 120,
#  'smaller': 121,
#  'latino': 122,
#  'nearly': 123,
#  'americans': 124,
#  'slipped': 125,
#  'middle': 126,
#  'class': 127,
#  'poverty': 128,
#  'mitt': 129,
#  'romney': 130,
#  'governor': 131,
#  'massachusetts': 132,
#  'didnt': 133,
#  'slow': 134,
#  'rate': 135,
#  'growth': 136,
#  'government': 137,
#  'actually': 138,
#  'cut': 139,
#  'economy': 140,
#  'bled': 141,
#  'billion': 142,
#  'due': 143,
#  'shutdown': 144,
#  'most': 145,
#  'affordable': 146,
#  'act': 147,
#  'already': 148,
#  'sense': 149,
#  'waived': 150,
#  'otherwise': 151,
#  'suspended': 152,
#  'in': 153,
#  'election': 154,
#  'november': 155,
#  'percent': 156,
#  'american': 157,
#  'people': 158,
#  'chose': 159,
#  'young': 160,
#  'low': 161,
#  'income': 162,
#  'workers': 163,
#  'opposed': 164,
#  'requirement': 165,
#  'buy': 166,
#  'made': 167,
#  'motorcycles': 168,
#  'and': 169,
#  'said': 170,
#  'provisions': 171,
#  'quote': 172,
#  'disgraceful': 173,
#  'u': 174,
#  's': 175,
#  'rep': 176,
#  'ron': 177,
#  'kind': 178,
#  'd': 179,
#  'wis': 180,
#  'fellow': 181,
#  'democrats': 182,
#  'went': 183,
#  'spending': 184,
#  'spree': 185,
#  'credit': 186,
#  'card': 187,
#  'maxed': 188,
#  'water': 189,
#  'rates': 190,
#  'manila': 191,
#  'philippines': 192,
#  'raised': 193,
#  'subsidiary': 194,
#  'world': 195,
#  'bank': 196,
#  'became': 197,
#  'partial': 198,
#  'owner': 199,
#  'almost': 200,
#  'left': 201,
#  'puerto': 202,
#  'rico': 203,
#  'women': 204,
#  'men': 205,
#  'making': 206,
#  'less': 207,
#  'adjust': 208,
#  'inflation': 209,
#  'kitzhaber': 210,
#  'elected': 211,
#  'united': 212,
#  'states': 213,
#  'highest': 214,
#  'corporate': 215,
#  'tax': 216,
#  'we': 217,
#  'best': 218,
#  'auto': 219,
#  'industry': 220,
#  'america': 221,
#  'scott': 222,
#  'walker': 223,
#  'favors': 224,
#  'cutting': 225,
#  'families': 226,
#  'children': 227,
#  'wants': 228,
#  'get': 229,
#  'rid': 230,
#  'planned': 231,
#  'parenthood': 232,
#  'dont': 233,
#  'know': 234,
#  'jonathan': 235,
#  'gruber': 236,
#  'hate': 237,
#  'crimes': 238,
#  'muslims': 239,
#  'mosques': 240,
#  'tripled': 241,
#  'paris': 242,
#  'san': 243,
#  'bernardino': 244,
#  'rick': 245,
#  'perry': 246,
#  'never': 247,
#  'lost': 248,
#  'remains': 249,
#  'texas': 250,
#  'governorship': 251,
#  'three': 252,
#  'times': 253,
#  'landslide': 254,
#  'elections': 255,
#  'isis': 256,
#  'supporter': 257,
#  'tweeted': 258,
#  'shooting': 259,
#  'began': 260,
#  'chattanooga': 261,
#  'tenn': 262,
#  'youth': 263,
#  'unemployment': 264,
#  'minority': 265,
#  'communities': 266,
#  'paul': 267,
#  'ryan': 268,
#  'still': 269,
#  'endorsing': 270,
#  'trump': 271,
#  'if': 272,
#  'look': 273,
#  'right': 274,
#  'work': 275,
#  'constantly': 276,
#  'budget': 277,
#  'deficits': 278,
#  'good': 279,
#  'business': 280,
#  'climates': 281,
#  'what': 282,
#  'obama': 283,
#  'going': 284,
#  'come': 285,
#  'next': 286,
#  'several': 287,
#  'months': 288,
#  'youre': 289,
#  'even': 290,
#  'able': 291,
#  'burn': 292,
#  'limitedly': 293,
#  'existing': 294,
#  'plants': 295,
#  'taxes': 296,
#  'today': 297,
#  'businesses': 298,
#  'pay': 299,
#  'mark': 300,
#  'pryor': 301,
#  'votes': 302,
#  'federal': 303,
#  'thinks': 304,
#  'authority': 305,
#  'regulate': 306,
#  'toilet': 307,
#  'seats': 308,
#  'austin': 309,
#  'city': 310,
#  'basically': 311,
#  'doubled': 312,
#  'size': 313,
#  'every': 314,
#  'founded': 315,
#  'nuclear': 316,
#  'test': 317,
#  'conducted': 318,
#  'nation': 319,
#  'earth': 320,
#  'th': 321,
#  'five': 322,
#  'permanent': 323,
#  'members': 324,
#  'n': 325,
#  'security': 326,
#  'council': 327,
#  'tests': 328,
#  'case': 329,
#  'catastrophic': 330,
#  'event': 331,
#  'atlanta': 332,
#  'area': 333,
#  'offices': 334,
#  'centers': 335,
#  'disease': 336,
#  'control': 337,
#  'prevention': 338,
#  'self': 339,
#  'destruct': 340,
#  'under': 341,
#  'added': 342,
#  'trillion': 343,
#  'debt': 344,
#  'weve': 345,
#  'supreme': 346,
#  'court': 347,
#  'justice': 348,
#  'suggested': 349,
#  'cases': 350,
#  'decided': 351,
#  'based': 352,
#  'south': 353,
#  'african': 354,
#  'law': 355,
#  'marco': 356,
#  'rubio': 357,
#  'skipped': 358,
#  'defense': 359,
#  'including': 360,
#  'one': 361,
#  'arm': 362,
#  'kurds': 363,
#  'fight': 364,
#  'david': 365,
#  'cicilline': 366,
#  'responsible': 367,
#  'loan': 368,
#  'guarantee': 369,
#  'solyndra': 370,
#  'failed': 371,
#  'solar': 372,
#  'company': 373,
#  'ohio': 374,
#  'item': 375,
#  'later': 376,
#  'signed': 377,
#  'gov': 378,
#  'kasich': 379,
#  'requires': 380,
#  'seeking': 381,
#  'abortion': 382,
#  'undergo': 383,
#  'mandatory': 384,
#  'vaginal': 385,
#  'probe': 386,
#  'director': 387,
#  'homeland': 388,
#  'cannot': 389,
#  'use': 390,
#  'terrorist': 391,
#  'attack': 392,
#  'instead': 393,
#  'substitutes': 394,
#  'man': 395,
#  'disaster': 396,
#  'hispanic': 397,
#  'obamacare': 398,
#  'provide': 399,
#  'insurance': 400,
#  'non': 401,
#  'residents': 402,
#  'illegally': 403,
#  'barack': 404,
#  'exactly': 405,
#  'none': 406,
#  'deficit': 407,
#  'reduction': 408,
#  'commissions': 409,
#  'ideas': 410,
#  'not': 411,
#  'changed': 412,
#  'rules': 413,
#  'engagement': 414,
#  'probably': 415,
#  'capt': 416,
#  'humayun': 417,
#  'khans': 418,
#  'life': 419,
#  'co': 420,
#  'sponsored': 421,
#  'would': 422,
#  'jail': 423,
#  'flag': 424,
#  'burners': 425,
#  'paperback': 426,
#  'edition': 427,
#  'romneys': 428,
#  'book': 429,
#  'deleted': 430,
#  'line': 431,
#  'individual': 432,
#  'model': 433,
#  'country': 434,
#  'maggie': 435,
#  'hassan': 436,
#  'tuition': 437,
#  'terry': 438,
#  'mcauliffe': 439,
#  'invented': 440,
#  'scheme': 441,
#  'rent': 442,
#  'lincoln': 443,
#  'bedroom': 444,
#  'created': 445,
#  'jobs': 446,
#  'half': 447,
#  'york': 448,
#  'state': 449,
#  'private': 450,
#  'sector': 451,
#  'ever': 452,
#  'towns': 453,
#  'west': 454,
#  'truck': 455,
#  'georgia': 456,
#  'earn': 457,
#  'cents': 458,
#  'dollar': 459,
#  'earned': 460,
#  'a': 461,
#  'system': 462,
#  'verifies': 463,
#  'employees': 464,
#  'authorized': 465,
#  'inaccurate': 466,
#  'anywhere': 467,
#  'way': 468,
#  'excess': 469,
#  'they': 470,
#  'build': 471,
#  'wall': 472,
#  'ago': 473,
#  'long': 474,
#  'like': 475,
#  'couldnt': 476,
#  'environmental': 477,
#  'impact': 478,
#  'statements': 479,
#  'sen': 480,
#  'campaign': 481,
#  'announced': 482,
#  'choosing': 483,
#  'cabinet': 484,
#  'latinos': 485,
#  'registered': 486,
#  'turned': 487,
#  'only': 488,
#  'public': 489,
#  'high': 490,
#  'schools': 491,
#  'offer': 492,
#  'pe': 493,
#  'classes': 494,
#  'republican': 495,
#  'candidate': 496,
#  'around': 497,
#  'on': 498,
#  'military': 499,
#  'recruiters': 500,
#  'harvard': 501,
#  'elena': 502,
#  'kagan': 503,
#  'position': 504,
#  'ruled': 505,
#  'unanimously': 506,
#  'wrong': 507,
#  'there': 508,
#  'school': 509,
#  'teachers': 510,
#  'mayor': 511,
#  '[providence]': 512,
#  'sanctuary': 513,
#  'transgender': 514,
#  'individuals': 515,
#  'chance': 516,
#  'murdered': 517,
#  'at': 518,
#  'bain': 519,
#  'capital': 520,
#  'helped': 521,
#  'early': 522,
#  'childhood': 523,
#  'learning': 524,
#  'called': 525,
#  'bright': 526,
#  'horizons': 527,
#  'lady': 528,
#  'michelle': 529,
#  'rightly': 530,
#  'praised': 531,
#  'rushed': 532,
#  'dayton': 533,
#  'chatter': 534,
#  'social': 535,
#  'media': 536,
#  'posts': 537,
#  'phil': 538,
#  'gingrey': 539,
#  'gave': 540,
#  'power': 541,
#  'electronically': 542,
#  'spy': 543,
#  'without': 544,
#  'warrant': 545,
#  'alex': 546,
#  'sink': 547,
#  'funneled': 548,
#  'quarters': 549,
#  'dollars': 550,
#  'bid': 551,
#  'contracts': 552,
#  'take': 553,
#  'population': 554,
#  'virginia': 555,
#  'net': 556,
#  'zero': 557,
#  'job': 558,
#  'creation': 559,
#  'bob': 560,
#  'mcdonnell': 561,
#  'home': 562,
#  'values': 563,
#  'florida': 564,
#  'collapsed': 565,
#  'construction': 566,
#  'foreclosure': 567,
#  'arizona': 568,
#  'immigration': 569,
#  'police': 570,
#  'officer': 571,
#  'stop': 572,
#  'anyone': 573,
#  'appears': 574,
#  'reasonably': 575,
#  'suspicious': 576,
#  'undocumented': 577,
#  'war': 578,
#  'ii': 579,
#  'single': 580,
#  'biggest': 581,
#  'factor': 582,
#  'driving': 583,
#  'during': 584,
#  'recession': 585,
#  'consumer': 586,
#  'native': 587,
#  'perversity': 588,
#  'begun': 589,
#  'save': 590,
#  'savings': 591,
#  'whether': 592,
#  'nominee': 593,
#  'forthcoming': 594,
#  'confirmation': 595,
#  'hearings': 596,
#  'homeless': 597,
#  'veteran': 598,
#  'charlie': 599,
#  'crist': 600,
#  'cuts': 601,
#  'medicare': 602,
#  'advantage': 603,
#  'program': 604,
#  'think': 605,
#  'unacceptable': 606,
#  'chinese': 607,
#  'larger': 608,
#  'wind': 609,
#  'panels': 610,
#  'photovoltaic': 611,
#  'manufacturing': 612,
#  'europe': 613,
#  'put': 614,
#  'together': 615,
#  'forget': 616,
#  'brown': 617,
#  'let': 618,
#  'employers': 619,
#  'deny': 620,
#  'coverage': 621,
#  'birth': 622,
#  'point': 623,
#  'lives': 624,
#  'past': 625,
#  'egypt': 626,
#  'great': 627,
#  'strides': 628,
#  'democratic': 629,
#  'amount': 630,
#  'attention': 631,
#  'paid': 632,
#  'week': 633,
#  'chris': 634,
#  'christie': 635,
#  'makes': 636,
#  'benghazi': 637,
#  'pale': 638,
#  'significance': 639,
#  'steve': 640,
#  'southerland': 641,
#  'voted': 642,
#  'keep': 643,
#  'perrys': 644,
#  'import': 645,
#  'nurses': 646,
#  'countries': 647,
#  'criminal': 648,
#  'crime': 649,
#  'transport': 650,
#  'dentures': 651,
#  'across': 652,
#  'lines': 653,
#  'built': 654,
#  'prison': 655,
#  'days': 656,
#  'mass': 657,
#  'incarceration': 658,
#  'explosion': 659,
#  'nonviolent': 660,
#  'offenders': 661,
#  'plan': 662,
#  'provides': 663,
#  'virtually': 664,
#  'nothing': 665,
#  'burdened': 666,
#  'fastest': 667,
#  'growing': 668,
#  'increases': 669,
#  'major': 670,
#  'phoenix': 671,
#  'no': 672,
#  'kidnapping': 673,
#  'belong': 674,
#  'afl': 675,
#  'cio': 676,
#  'commissioner': 677,
#  'cant': 678,
#  'squat': 679,
#  'poll': 680,
#  'found': 681,
#  'could': 682,
#  'beat': 683,
#  'eight': 684,
#  'points': 685,
#  'ronald': 686,
#  'reagan': 687,
#  'sent': 688,
#  'troops': 689,
#  'conflict': 690,
#  'circumstance': 691,
#  'grenada': 692,
#  'peacekeeping': 693,
#  'setting': 694,
#  'lebanon': 695,
#  'jolly': 696,
#  'privatizing': 697,
#  'did': 698,
#  'us': 699,
#  'lowest': 700,
#  'depression': 701,
#  'average': 702,
#  'student': 703,
#  'pocket': 704,
#  'universities': 705,
#  'much': 706,
#  'spend': 707,
#  'cellphones': 708,
#  'died': 709,
#  'gunfire': 710,
#  'wars': 711,
#  'countrys': 712,
#  'effect': 713,
#  'mean': 714,
#  'bill': 715,
#  'facing': 716,
#  'millions': 717,
#  'modified': 718,
#  'mortgage': 719,
#  'short': 720,
#  'sale': 721,
#  'lender': 722,
#  'department': 723,
#  'agricultures': 724,
#  'website': 725,
#  'freshfromflorida': 726,
#  'com': 727,
#  'used': 728,
#  'permit': 729,
#  'carry': 730,
#  'loaded': 731,
#  'hidden': 732,
#  'gun': 733,
#  'leaving': 734,
#  'house': 735,
#  'streetcar': 736,
#  'expected': 737,
#  'create': 738,
#  'totaling': 739,
#  'raising': 740,
#  'minimum': 741,
#  'wage': 742,
#  'hour': 743,
#  'help': 744,
#  'lift': 745,
#  'secretary': 746,
#  'kerry': 747,
#  'senator': 748,
#  'flew': 749,
#  'managua': 750,
#  'met': 751,
#  'communist': 752,
#  'dictator': 753,
#  'daniel': 754,
#  'ortega': 755,
#  'accused': 756,
#  'engaging': 757,
#  'terrorism': 758,
#  'nato': 759,
#  'opening': 760,
#  'terror': 761,
#  'division': 762,
#  'im': 763,
#  'sure': 764,
#  'largely': 765,
#  'saying': 766,
#  'criticism': 767,
#  'always': 768,
#  'prochoice': 769,
#  'rating': 770,
#  'gina': 771,
#  'raimondo': 772,
#  'office': 773,
#  'investment': 774,
#  'fees': 775,
#  'pension': 776,
#  'portfolio': 777,
#  'gone': 778,
#  'annually': 779,
#  'day': 780,
#  'obamas': 781,
#  'longer': 782,
#  'lay': 783,
#  'firefighters': 784,
#  'officers': 785,
#  'of': 786,
#  'k': 787,
#  'old': 788,
#  'thirds': 789,
#  'wisconsinites': 790,
#  'receiving': 791,
#  'checks': 792,
#  'required': 793,
#  'search': 794,
#  'current': 795,
#  'exemptions': 796,
#  'reforms': 797,
#  'premium': 798,
#  'family': 799,
#  'go': 800,
#  'per': 801,
#  'irs': 802,
#  'also': 803,
#  'investigated': 804,
#  'liberal': 805,
#  'groups': 806,
#  'progressive': 807,
#  'name': 808,
#  'looking': 809,
#  'everybody': 810,
#  'promised': 811,
#  'creating': 812,
#  'pace': 813,
#  'meet': 814,
#  'prime': 815,
#  'minister': 816,
#  'benjamin': 817,
#  'netanyahu': 818,
#  'majority': 819,
#  'marry': 820,
#  'freely': 821,
#  'love': 822,
#  'say': 823,
#  'reps': 824,
#  'peter': 825,
#  'defazio': 826,
#  'earl': 827,
#  'blumenauer': 828,
#  'socialists': 829,
#  'openly': 830,
#  'serving': 831,
#  'congress': 832,
#  'rudy': 833,
#  'giuliani': 834,
#  'underqualified': 835,
#  'seek': 836,
#  'presidency': 837,
#  'about': 838,
#  'presidents': 839,
#  'governors;': 840,
#  'senators': 841,
#  'after': 842,
#  'britains': 843,
#  'leave': 844,
#  'european': 845,
#  'union': 846,
#  'within': 847,
#  'hours': 848,
#  'medicaid': 849,
#  'declined': 850,
#  'second': 851,
#  'constables': 852,
#  'duty': 853,
#  'prepaid': 854,
#  'college': 855,
#  'columbus': 856,
#  'contribute': 857,
#  'guaranteed': 858,
#  'check': 859,
#  'pensions': 860,
#  'as': 861,
#  'cfo': 862,
#  'shut': 863,
#  'krakow': 864,
#  'scam': 865,
#  'refunded': 866,
#  'josephine': 867,
#  'victims': 868,
#  'con': 869,
#  'you': 870,
#  'getting': 871,
#  'computer': 872,
#  'sciences': 873,
#  'degrees': 874,
#  'plus': 875,
#  'air': 876,
#  'force': 877,
#  'taxpayers': 878,
#  'fund': 879,
#  'fantasy': 880,
#  'football': 881,
#  'league': 882,
#  'hussein': 883,
#  'courts': 884,
#  'accept': 885,
#  'islamic': 886,
#  'sharia': 887,
#  'domestic': 888,
#  'disputes': 889,
#  'murders': 890,
#  'committed': 891,
#  'guns': 892,
#  'legally': 893,
#  'purchase': 894,
#  'some': 895,
#  'neighborhood': 896,
#  'closing': 897,
#  'he': 898,
#  'told': 899,
#  'gay': 900,
#  'organizers': 901,
#  'stronger': 902,
#  'advocate': 903,
#  'special': 904,
#  'rights': 905,
#  'ted': 906,
#  'kennedy': 907,
#  'speaker': 908,
#  'consistently': 909,
#  'offered': 910,
#  'leaner': 911,
#  'budgets': 912,
#  'halfway': 913,
#  'goal': 914,
#  'seven': 915,
#  'saysmichael': 916,
#  'bennet': 917,
#  'close': 918,
#  'guantanamo': 919,
#  'bay': 920,
#  'prisonand': 921,
#  'bring': 922,
#  'terrorists': 923,
#  'colorado': 924,
#  'oregonians': 925,
#  'amazing': 926,
#  'donations': 927,
#  'hes': 928,
#  'syrian': 929,
#  'iraqi': 930,
#  'refugees': 931,
#  'research': 932,
#  'shows': 933,
#  'vast': 934,
#  'arriving': 935,
#  'immigrants': 936,
#  'believe': 937,
#  'source': 938,
#  'prosperity': 939,
#  'thats': 940,
#  'support': 941,
#  'newt': 942,
#  'gingrichs': 943,
#  'offers': 944,
#  'doorway': 945,
#  'amnesty': 946,
#  'mr': 947,
#  'caprio': 948,
#  'career': 949,
#  'politician': 950,
#  'rhode': 951,
#  'island': 952,
#  'temporary': 953,
#  'disability': 954,
#  'jersey': 955,
#  'interest': 956,
#  'exceed': 957,
#  'all': 958,
#  'revenue': 959,
#  'money': 960,
#  'street': 961,
#  'anybody': 962,
#  'donald': 963,
#  'proliferation': 964,
#  'ok': 965,
#  'taken': 966,
#  'lobbyists': 967,
#  'expressly': 968,
#  'bans': 969,
#  'racial': 970,
#  'profiling': 971,
#  'begging': 972,
#  'send': 973,
#  'coast': 974,
#  'guard': 975,
#  'patrol': 976,
#  'lakes': 977,
#  'mexico': 978,
#  'border': 979,
#  'va': 980,
#  'over': 981,
#  'veterans': 982,
#  'waiting': 983,
#  'were': 984,
#  'rob': 985,
#  'cornilles': 986,
#  'dan': 987,
#  'branch': 988,
#  'tried': 989,
#  'expand': 990,
#  'steady': 991,
#  'progress': 992,
#  'improving': 993,
#  'michigan': 994,
#  'bottle': 995,
#  'deposit': 996,
#  'afford': 997,
#  'redemptions': 998,
#  'profit': 999,
#  ...}

# %% [markdown]
# ## Create One-hot Encoding

# %%
label_to_ix = {"True": 1, "False": 0}

def label_one_hot(x):
    return 1 if x else 0

data['label_one_hot'] = data.loc[:,'Label'].apply(label_one_hot)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array  label_one_hot
# 0  [says, annies, list, political, group, support...              0
# 1  [when, decline, coal, start, it, started, natu...              1
# 2  [hillary, clinton, agrees, john, mccain, votin...              1
