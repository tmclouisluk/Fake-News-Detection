# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
import random

# %% [markdown]
# ## Load data

# %%
TRAIN_CSV_PATH = "./data/train.csv"
data = pd.read_csv(TRAIN_CSV_PATH, index_col=False)
data.head(3)
# Out:
#                                            Statement  Label
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True

# %% [markdown]
# ## Clean digits, punctuation and symbols

# %%
def clean_text(x):
    text = ''.join([i for i in x if not i.isdigit()])
    text = re.sub("[!\?@^&.,/#$+%*:()'\"-]", ' ', text)
    return text

data['cleaned_statement'] = data.loc[:,'Statement'].apply(clean_text)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...

# %% [markdown]
# ## Download NLTK Stopwords model

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/louis/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Clean stopwords and lowercase

# %%
def clean_stopwords(x):
    text = x.split() 
    filtered_words = [word.lower() for word in text if word not in stopwords.words('english')]
    return filtered_words

data['text_array'] = data.loc[:,'cleaned_statement'].apply(clean_stopwords)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array
# 0  [says, annies, list, political, group, support...
# 1  [when, decline, coal, start, it, started, natu...
# 2  [hillary, clinton, agrees, john, mccain, votin...

# %% [markdown]
# ## Create text tokens from data

# %%
word_to_ix = {}
total_text_array = []
for text_array in data['text_array']:
    for word in text_array:
        total_text_array.append(word)

random.shuffle(total_text_array)    

for word in total_text_array:
    if word not in word_to_ix:
        word_to_ix[word] = len(word_to_ix)

word_to_ix
# Out:
# {'health': 0,
#  'trump': 1,
#  'best': 2,
#  'one': 3,
#  'despite': 4,
#  'get': 5,
#  'accommodate': 6,
#  'thanks': 7,
#  'capita': 8,
#  'general': 9,
#  'losses': 10,
#  'religious': 11,
#  'allied': 12,
#  'last': 13,
#  'furloughed': 14,
#  'suspend': 15,
#  'mistake': 16,
#  'requiring': 17,
#  'two': 18,
#  'university': 19,
#  'theu': 20,
#  'driving': 21,
#  'david': 22,
#  'americas': 23,
#  'after': 24,
#  'killed': 25,
#  'long': 26,
#  'isnt': 27,
#  'tax': 28,
#  'river': 29,
#  'jerseys': 30,
#  'climate': 31,
#  'time': 32,
#  'ohios': 33,
#  'increased': 34,
#  'confined': 35,
#  'staff': 36,
#  'lower': 37,
#  'grown': 38,
#  'pay': 39,
#  'job': 40,
#  'people': 41,
#  'providences': 42,
#  'unemployment': 43,
#  'opposed': 44,
#  'there': 45,
#  'taft': 46,
#  'ii': 47,
#  'adults': 48,
#  'the': 49,
#  'year': 50,
#  'says': 51,
#  'paid': 52,
#  'infarction': 53,
#  'running': 54,
#  'maddox': 55,
#  'gallon': 56,
#  'regulations': 57,
#  'candidate': 58,
#  'rate': 59,
#  'passing': 60,
#  'changed': 61,
#  'pace': 62,
#  'goes': 63,
#  'i': 64,
#  'states': 65,
#  'asthma': 66,
#  'elementary': 67,
#  'easier': 68,
#  'former': 69,
#  'percent': 70,
#  'budget': 71,
#  'youth': 72,
#  'since': 73,
#  'walker': 74,
#  'got': 75,
#  'standardized': 76,
#  'schrader': 77,
#  'individual': 78,
#  'ozone': 79,
#  'district': 80,
#  'holder': 81,
#  'indiana': 82,
#  'al': 83,
#  'revolution': 84,
#  'milwaukee': 85,
#  'education': 86,
#  'points': 87,
#  'contributed': 88,
#  'killing': 89,
#  'heller': 90,
#  'they': 91,
#  'unemployed': 92,
#  'assault': 93,
#  'falks': 94,
#  'house': 95,
#  'additional': 96,
#  'records': 97,
#  'universities': 98,
#  'prevention': 99,
#  'bowe': 100,
#  'authorize': 101,
#  'unions': 102,
#  'taxes': 103,
#  'sudden': 104,
#  'stimulus': 105,
#  'direct': 106,
#  'hillary': 107,
#  'family': 108,
#  'business': 109,
#  'it': 110,
#  'banks': 111,
#  'term': 112,
#  'commitments': 113,
#  'gas': 114,
#  'science': 115,
#  'sales': 116,
#  'suggested': 117,
#  'freedom': 118,
#  'prices': 119,
#  'technical': 120,
#  'senate': 121,
#  'immigration': 122,
#  'today': 123,
#  'mocked': 124,
#  'ages': 125,
#  'basis': 126,
#  'lowest': 127,
#  'know': 128,
#  'even': 129,
#  'incidents': 130,
#  'solar': 131,
#  'would': 132,
#  'much': 133,
#  'arizona': 134,
#  'barack': 135,
#  'presidential': 136,
#  'featured': 137,
#  'ruling': 138,
#  'per': 139,
#  'spending': 140,
#  'reported': 141,
#  'we': 142,
#  'release': 143,
#  'workers': 144,
#  '[gun': 145,
#  'public': 146,
#  'raised': 147,
#  'jobs': 148,
#  'u': 149,
#  'expanded': 150,
#  'hesecured': 151,
#  'using': 152,
#  'earn': 153,
#  'corn': 154,
#  'rick': 155,
#  'years': 156,
#  'beck': 157,
#  'care': 158,
#  'middle': 159,
#  'traffic': 160,
#  'parenthood': 161,
#  'mothers': 162,
#  'monument': 163,
#  'many': 164,
#  'women': 165,
#  'america': 166,
#  'leaders': 167,
#  'shootings': 168,
#  'within': 169,
#  'salary': 170,
#  'growing': 171,
#  'abolish': 172,
#  'x': 173,
#  'green': 174,
#  'foreclosure': 175,
#  'bus': 176,
#  'israel': 177,
#  'romney': 178,
#  'donald': 179,
#  'americans': 180,
#  'ronald': 181,
#  'demand': 182,
#  'delay': 183,
#  'lot': 184,
#  'raise': 185,
#  'win': 186,
#  'days': 187,
#  'obama': 188,
#  'obese': 189,
#  'going': 190,
#  'struggling': 191,
#  'million': 192,
#  'president': 193,
#  'life': 194,
#  'ayotte': 195,
#  'energy': 196,
#  'during': 197,
#  'retires': 198,
#  'use': 199,
#  'hospitals': 200,
#  'bankruptcy': 201,
#  'shows': 202,
#  'least': 203,
#  'illegal': 204,
#  'cent': 205,
#  'branch': 206,
#  'on': 207,
#  'appointments': 208,
#  'not': 209,
#  'ration': 210,
#  'said': 211,
#  'benson': 212,
#  'federal': 213,
#  'nominee': 214,
#  'candidates': 215,
#  'permits': 216,
#  'easily': 217,
#  'months': 218,
#  'indeed': 219,
#  'department': 220,
#  'based': 221,
#  'protecting': 222,
#  'vote': 223,
#  'gun': 224,
#  'respect': 225,
#  'significantly': 226,
#  'military': 227,
#  'affect': 228,
#  'government': 229,
#  'now': 230,
#  'right': 231,
#  'started': 232,
#  'laws': 233,
#  'percentage': 234,
#  'christie': 235,
#  'trade': 236,
#  'determined': 237,
#  'profits': 238,
#  'background': 239,
#  'pelosi': 240,
#  'across': 241,
#  'gambler': 242,
#  'burdened': 243,
#  'inherited': 244,
#  'supremacist': 245,
#  'thats': 246,
#  'component': 247,
#  'took': 248,
#  'employers': 249,
#  'lunch': 250,
#  'ohio': 251,
#  'republicans': 252,
#  'period': 253,
#  'check': 254,
#  'clear': 255,
#  'study': 256,
#  'husband': 257,
#  'four': 258,
#  'a': 259,
#  'cartel': 260,
#  'gives': 261,
#  'numbers': 262,
#  'track': 263,
#  'doesnt': 264,
#  'papers': 265,
#  'muslim': 266,
#  'nuclear': 267,
#  'due': 268,
#  'another': 269,
#  'twice': 270,
#  'dont': 271,
#  'republican': 272,
#  'finances': 273,
#  'biennium': 274,
#  'touch': 275,
#  'grade': 276,
#  'work': 277,
#  '[u]nlike': 278,
#  'equal': 279,
#  'filipino': 280,
#  'd': 281,
#  'vehicular': 282,
#  'partnership': 283,
#  'pain': 284,
#  'ros': 285,
#  'school': 286,
#  'shaheen': 287,
#  'shades': 288,
#  'industry': 289,
#  'property': 290,
#  'reed': 291,
#  'inflation': 292,
#  'flip': 293,
#  'among': 294,
#  'con': 295,
#  'georgia': 296,
#  'price': 297,
#  'nation': 298,
#  'schools': 299,
#  'austinites': 300,
#  'open': 301,
#  'voting': 302,
#  'first': 303,
#  'top': 304,
#  'prosecuted': 305,
#  'saw': 306,
#  'relief': 307,
#  'jackow': 308,
#  'race': 309,
#  'together': 310,
#  'ad': 311,
#  'marlins': 312,
#  'prisons': 313,
#  'coverage': 314,
#  'january': 315,
#  'increase': 316,
#  'force': 317,
#  'congress': 318,
#  'student': 319,
#  'program': 320,
#  'take': 321,
#  'recent': 322,
#  'wisconsin': 323,
#  'later': 324,
#  'february': 325,
#  'porn': 326,
#  'korea': 327,
#  'national': 328,
#  'cut': 329,
#  'wendy': 330,
#  'state': 331,
#  'every': 332,
#  'districts': 333,
#  'pop': 334,
#  'sex': 335,
#  'wage': 336,
#  'campaigns': 337,
#  'healthcare': 338,
#  'biggest': 339,
#  'legislators': 340,
#  'children': 341,
#  'past': 342,
#  'madison': 343,
#  'possibly': 344,
#  'act': 345,
#  'bonds': 346,
#  'afford': 347,
#  'law': 348,
#  'cause': 349,
#  'lawyer': 350,
#  'millions': 351,
#  'minority': 352,
#  'citizens': 353,
#  'protection': 354,
#  'bill': 355,
#  'civil': 356,
#  'iowa': 357,
#  'firearm': 358,
#  'russia': 359,
#  'created': 360,
#  'afghanistan': 361,
#  'modern': 362,
#  'cites': 363,
#  'city': 364,
#  'zones': 365,
#  'day': 366,
#  'abortion': 367,
#  'rights': 368,
#  'florida': 369,
#  'facilities': 370,
#  'zika': 371,
#  'pass': 372,
#  'commerce': 373,
#  'her': 374,
#  'reform': 375,
#  'new': 376,
#  'united': 377,
#  'town': 378,
#  'food': 379,
#  'cio': 380,
#  'ceiling': 381,
#  'funded': 382,
#  'virginias': 383,
#  'personal': 384,
#  'june': 385,
#  'experience': 386,
#  'perry': 387,
#  'earth': 388,
#  'clinton': 389,
#  'employment': 390,
#  'black': 391,
#  'really': 392,
#  'planet': 393,
#  'committee': 394,
#  'saved': 395,
#  'rob': 396,
#  'economy': 397,
#  'times': 398,
#  'lost': 399,
#  'try': 400,
#  'prime': 401,
#  'aids': 402,
#  'cancer': 403,
#  'tonight': 404,
#  'away': 405,
#  'always': 406,
#  'dakotas': 407,
#  'train': 408,
#  'page': 409,
#  'chile': 410,
#  'medical': 411,
#  'blame': 412,
#  'average': 413,
#  'melania': 414,
#  'american': 415,
#  'substance': 416,
#  'enact': 417,
#  'profit': 418,
#  'virginia': 419,
#  'billion': 420,
#  'world': 421,
#  'veteran': 422,
#  'none': 423,
#  'under': 424,
#  'man': 425,
#  'affordable': 426,
#  'became': 427,
#  'charlie': 428,
#  'jersey': 429,
#  'young': 430,
#  'families': 431,
#  'court': 432,
#  'island': 433,
#  'higher': 434,
#  'orders': 435,
#  'ryan': 436,
#  'low': 437,
#  'plant': 438,
#  'youre': 439,
#  'social': 440,
#  'mccain': 441,
#  'country': 442,
#  'insurance': 443,
#  'thing': 444,
#  'administration': 445,
#  'campaign': 446,
#  'tried': 447,
#  'worker': 448,
#  'reflect': 449,
#  'gaza': 450,
#  'poor': 451,
#  'scott': 452,
#  'proactive': 453,
#  'interrogations': 454,
#  'part': 455,
#  'frankly': 456,
#  'natural': 457,
#  'genetically': 458,
#  'market': 459,
#  'officials': 460,
#  'help': 461,
#  'illegally': 462,
#  'violent': 463,
#  'dollars': 464,
#  'action': 465,
#  'environmentalists': 466,
#  'prohibition': 467,
#  'way': 468,
#  'control': 469,
#  'hate': 470,
#  'humans': 471,
#  'plan': 472,
#  'ends': 473,
#  'trillion': 474,
#  'count': 475,
#  'phil': 476,
#  'violence': 477,
#  'worst': 478,
#  'highest': 479,
#  'plants': 480,
#  'unfair': 481,
#  'minister': 482,
#  'groping': 483,
#  'bridge': 484,
#  'greater': 485,
#  'raising': 486,
#  'chair': 487,
#  'support': 488,
#  'seven': 489,
#  'marco': 490,
#  'langevin': 491,
#  'takeover': 492,
#  'costly': 493,
#  'detroit': 494,
#  'stamps': 495,
#  'kurt': 496,
#  'require': 497,
#  'in': 498,
#  'floridas': 499,
#  'give': 500,
#  'increases': 501,
#  'trans': 502,
#  'premiums': 503,
#  'water': 504,
#  'bank': 505,
#  'dolls': 506,
#  'jeb': 507,
#  'persons': 508,
#  'texas': 509,
#  'iran': 510,
#  'say': 511,
#  'hip': 512,
#  'sense': 513,
#  'countries': 514,
#  'spike': 515,
#  'dire': 516,
#  'pro': 517,
#  'else': 518,
#  'approval': 519,
#  'mary': 520,
#  'childs': 521,
#  'mexican': 522,
#  'progressive': 523,
#  'amendment': 524,
#  'nomination': 525,
#  'position': 526,
#  'systems': 527,
#  'connie': 528,
#  'fire': 529,
#  'three': 530,
#  'prop': 531,
#  'arms': 532,
#  'latest': 533,
#  'anything': 534,
#  'terrible': 535,
#  'us': 536,
#  'statewide': 537,
#  'added': 538,
#  'taxpayer': 539,
#  'oral': 540,
#  'showed': 541,
#  'temporarily': 542,
#  'deportations': 543,
#  'turns': 544,
#  'denies': 545,
#  'john': 546,
#  'implement': 547,
#  'thousand': 548,
#  'glorifying': 549,
#  'come': 550,
#  'destination': 551,
#  'mandate': 552,
#  'slash': 553,
#  'paying': 554,
#  'kemp': 555,
#  'gdp': 556,
#  'empirical': 557,
#  'cities': 558,
#  'decisions': 559,
#  'speaker': 560,
#  'show': 561,
#  'medicare': 562,
#  'company': 563,
#  'aid': 564,
#  'buffalo': 565,
#  'hes': 566,
#  'loans': 567,
#  'protesters': 568,
#  'major': 569,
#  'argument': 570,
#  'brown': 571,
#  'five': 572,
#  'wolves': 573,
#  'pip': 574,
#  'books': 575,
#  'mine': 576,
#  'working': 577,
#  'considered': 578,
#  'theres': 579,
#  'special': 580,
#  'policy': 581,
#  'businesses': 582,
#  'options': 583,
#  'bush': 584,
#  'good': 585,
#  'expensive': 586,
#  'manchester': 587,
#  'probably': 588,
#  'austin': 589,
#  'hike': 590,
#  'funds': 591,
#  'minutes': 592,
#  'more': 593,
#  'county': 594,
#  'alcohol': 595,
#  'end': 596,
#  'were': 597,
#  'actually': 598,
#  'occidental': 599,
#  'xl': 600,
#  'affairs': 601,
#  'serves': 602,
#  'spend': 603,
#  'felons': 604,
#  'wants': 605,
#  'cost': 606,
#  'paul': 607,
#  'existed': 608,
#  'name': 609,
#  'scheme': 610,
#  'stenciled': 611,
#  'largest': 612,
#  'well': 613,
#  'rates': 614,
#  'fits': 615,
#  'evidence': 616,
#  'make': 617,
#  'legal': 618,
#  'start': 619,
#  'as': 620,
#  'milken': 621,
#  'parked': 622,
#  'expansion': 623,
#  'visitors': 624,
#  'abbott': 625,
#  'eliminate': 626,
#  'horrendous': 627,
#  'fails': 628,
#  'half': 629,
#  'place': 630,
#  'islanders': 631,
#  'senators': 632,
#  'behind': 633,
#  'zero': 634,
#  'offshore': 635,
#  'w': 636,
#  'retirement': 637,
#  'mitt': 638,
#  'cantor': 639,
#  'rather': 640,
#  'mixed': 641,
#  'security': 642,
#  'deeply': 643,
#  'bring': 644,
#  'break': 645,
#  'doubled': 646,
#  'eight': 647,
#  'responsible': 648,
#  'must': 649,
#  'overseas': 650,
#  'principles': 651,
#  'allowed': 652,
#  'oil': 653,
#  'hundreds': 654,
#  'schultz': 655,
#  'crisis': 656,
#  'wall': 657,
#  'iraq': 658,
#  'elected': 659,
#  'ever': 660,
#  'corporate': 661,
#  'wont': 662,
#  'surplus': 663,
#  'dying': 664,
#  'add': 665,
#  'chores': 666,
#  'flopped': 667,
#  'real': 668,
#  'tent': 669,
#  'spent': 670,
#  'creflo': 671,
#  'fees': 672,
#  'nickel': 673,
#  'less': 674,
#  'what': 675,
#  'existing': 676,
#  'bulb': 677,
#  'skills': 678,
#  'convicted': 679,
#  'so': 680,
#  'no': 681,
#  'walmart': 682,
#  'group': 683,
#  'countering': 684,
#  'unfairness': 685,
#  'meal': 686,
#  's': 687,
#  'interstate': 688,
#  'ago': 689,
#  'faster': 690,
#  'golf': 691,
#  'lead': 692,
#  'over': 693,
#  'occupy': 694,
#  'doctored': 695,
#  'she': 696,
#  'services': 697,
#  'roughly': 698,
#  'becoming': 699,
#  'governor': 700,
#  'co': 701,
#  'wrestlers': 702,
#  'democratic': 703,
#  'taxpayers': 704,
#  'better': 705,
#  'face': 706,
#  'breaks': 707,
#  'marta': 708,
#  'sullivan': 709,
#  'any': 710,
#  'camera': 711,
#  'never': 712,
#  'kelly': 713,
#  'emails': 714,
#  'disproportionately': 715,
#  'sen': 716,
#  'creation': 717,
#  'jim': 718,
#  'losing': 719,
#  'because': 720,
#  'report': 721,
#  'change': 722,
#  'drivers': 723,
#  'discrimination': 724,
#  'china': 725,
#  'row': 726,
#  'history': 727,
#  'iv': 728,
#  'single': 729,
#  'coons': 730,
#  'risk': 731,
#  'caliber': 732,
#  'fast': 733,
#  'of': 734,
#  'able': 735,
#  'protect': 736,
#  'trusted': 737,
#  'self': 738,
#  'born': 739,
#  'establishment': 740,
#  'licenses': 741,
#  'veterans': 742,
#  'held': 743,
#  'benefit': 744,
#  'close': 745,
#  'medicaid': 746,
#  'election': 747,
#  'cash': 748,
#  'six': 749,
#  'meetings': 750,
#  'savings': 751,
#  'collectingsocial': 752,
#  'written': 753,
#  'takes': 754,
#  'allocation': 755,
#  'universal': 756,
#  'harshest': 757,
#  'levels': 758,
#  'abele': 759,
#  'filling': 760,
#  'bipartisan': 761,
#  'attended': 762,
#  'debt': 763,
#  'war': 764,
#  'nothing': 765,
#  'money': 766,
#  'portman': 767,
#  'repay': 768,
#  'about': 769,
#  'orientation': 770,
#  'abusers': 771,
#  'streetcar': 772,
#  'dead': 773,
#  'proposed': 774,
#  'bruun': 775,
#  'to': 776,
#  'panasonic': 777,
#  'drive': 778,
#  'nations': 779,
#  'earning': 780,
#  'debacle': 781,
#  'seniors': 782,
#  'programs': 783,
#  'called': 784,
#  'permanent': 785,
#  'doctors': 786,
#  'local': 787,
#  'immigrant': 788,
#  'taken': 789,
#  'thanked': 790,
#  'rich': 791,
#  'whos': 792,
#  'urged': 793,
#  'reid': 794,
#  'seamen': 795,
#  'stand': 796,
#  'worm': 797,
#  'underfunding': 798,
#  'parks': 799,
#  'problem': 800,
#  'undergraduate': 801,
#  'class': 802,
#  'allows': 803,
#  'utter': 804,
#  'person': 805,
#  'liberia': 806,
#  'rabid': 807,
#  'run': 808,
#  'isolated': 809,
#  'red': 810,
#  'gains': 811,
#  'iranians': 812,
#  'oppose': 813,
#  'rises': 814,
#  'unopposed': 815,
#  'japan': 816,
#  'anti': 817,
#  'bulbs': 818,
#  'majority': 819,
#  'may': 820,
#  'colorado': 821,
#  'little': 822,
#  'weve': 823,
#  'investment': 824,
#  'casting': 825,
#  'crimes': 826,
#  'treated': 827,
#  'lobbying': 828,
#  'californias': 829,
#  'gave': 830,
#  'locking': 831,
#  'depicts': 832,
#  'virtually': 833,
#  'deal': 834,
#  'advisers': 835,
#  'honest': 836,
#  'calculated': 837,
#  'number': 838,
#  'n': 839,
#  'an': 840,
#  'governments': 841,
#  'wealthy': 842,
#  'pensions': 843,
#  'projected': 844,
#  'labor': 845,
#  'expire': 846,
#  'disrespect': 847,
#  'troops': 848,
#  'lack': 849,
#  'avoidance': 850,
#  'comes': 851,
#  'ban': 852,
#  'justice': 853,
#  'saves': 854,
#  'cuts': 855,
#  'congressional': 856,
#  'consecutive': 857,
#  'estimates': 858,
#  'stop': 859,
#  'college': 860,
#  'ranks': 861,
#  'along': 862,
#  'combined': 863,
#  'if': 864,
#  'recovery': 865,
#  'package': 866,
#  'electorate': 867,
#  'scam': 868,
#  'toughest': 869,
#  'yesterday': 870,
#  'beliefs': 871,
#  'great': 872,
#  'put': 873,
#  'challenger': 874,
#  'service': 875,
#  'management': 876,
#  'acentral': 877,
#  'roads': 878,
#  'vaccine': 879,
#  'flint': 880,
#  'george': 881,
#  'consumers': 882,
#  'recently': 883,
#  'acknowledged': 884,
#  'deportation': 885,
#  'arent': 886,
#  'baggage': 887,
#  'let': 888,
#  'appropriations': 889,
#  'unaccompanied': 890,
#  'relations': 891,
#  'medium': 892,
#  'gov': 893,
#  'for': 894,
#  'romneys': 895,
#  'christmas': 896,
#  'survived': 897,
#  'hunting': 898,
#  'capabilities': 899,
#  'ticket': 900,
#  'renacci': 901,
#  'whites': 902,
#  'expected': 903,
#  'entry': 904,
#  'owners': 905,
#  'applying': 906,
#  'hikes': 907,
#  'rating': 908,
#  'back': 909,
#  'places': 910,
#  'air': 911,
#  'scores': 912,
#  'abolition': 913,
#  'washington': 914,
#  'legislated': 915,
#  'left': 916,
#  'amazon': 917,
#  'chairman': 918,
#  'transactions': 919,
#  'economic': 920,
#  'qaida': 921,
#  'rep': 922,
#  'wrong': 923,
#  'cast': 924,
#  'bay': 925,
#  'wisconsins': 926,
#  'akin': 927,
#  'gangs': 928,
#  'crime': 929,
#  'geneva': 930,
#  'thousands': 931,
#  'incomes': 932,
#  'things': 933,
#  'strong': 934,
#  'preventative': 935,
#  'super': 936,
#  'street': 937,
#  'cutting': 938,
#  'goal': 939,
#  'region': 940,
#  'wrote': 941,
#  'theyre': 942,
#  'sotomayor': 943,
#  'dovillas': 944,
#  'leave': 945,
#  'murder': 946,
#  'alone': 947,
#  'voters': 948,
#  'power': 949,
#  'cant': 950,
#  'democrats': 951,
#  'bailouts': 952,
#  'benefits': 953,
#  'child': 954,
#  'syria': 955,
#  'efforts': 956,
#  'midnight': 957,
#  'kits': 958,
#  'according': 959,
#  'clearly': 960,
#  'companies': 961,
#  'penn': 962,
#  'beyond': 963,
#  'daycare': 964,
#  'entire': 965,
#  'credit': 966,
#  'patrick': 967,
#  'invade': 968,
#  'prescription': 969,
#  'meeting': 970,
#  'fix': 971,
#  'assistance': 972,
#  'condition': 973,
#  'lobbyists': 974,
#  'pure': 975,
#  'ofsupporting': 976,
#  'enforcement': 977,
#  'fund': 978,
#  'kill': 979,
#  'begun': 980,
#  'carry': 981,
#  'rail': 982,
#  'nra': 983,
#  'homes': 984,
#  'illegals': 985,
#  'louisiana': 986,
#  'far': 987,
#  'bureaucrats': 988,
#  'drastically': 989,
#  'oversight': 990,
#  'returns': 991,
#  'planned': 992,
#  'ballparks': 993,
#  'spoken': 994,
#  'terrorists': 995,
#  'option': 996,
#  'questions': 997,
#  'donated': 998,
#  'winter': 999,
#  ...}

# %%
def text_tokenizer(x):
    tokens = []
    for text in x:
        token = word_to_ix[text]
        tokens.append(token)
    return tokens

data['text_token'] = data.loc[:,'text_array'].apply(text_tokenizer)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array  \
# 0  [says, annies, list, political, group, support...
# 1  [when, decline, coal, start, it, started, natu...
# 2  [hillary, clinton, agrees, john, mccain, votin...
#
#                                           text_token  label_one_hot
# 0  [51, 8621, 1107, 1291, 683, 1823, 1523, 5606, ...              0
# 1  [1053, 2050, 1179, 619, 110, 232, 457, 114, 24...              1
# 2  [107, 389, 3557, 546, 441, 302, 500, 881, 584,...              1

# %% [markdown]
# ## Create One-hot Encoding

# %%
label_to_ix = {"True": 1, "False": 0}

def label_one_hot(x):
    return 1 if x else 0

data['label_one_hot'] = data.loc[:,'Label'].apply(label_one_hot)
data.head(3)
# Out:
#                                            Statement  Label  \
# 0  Says the Annies List political group supports ...  False
# 1  When did the decline of coal start? It started...   True
# 2  Hillary Clinton agrees with John McCain "by vo...   True
#
#                                    cleaned_statement  \
# 0  Says the Annies List political group supports ...
# 1  When did the decline of coal start  It started...
# 2  Hillary Clinton agrees with John McCain  by vo...
#
#                                           text_array  \
# 0  [says, annies, list, political, group, support...
# 1  [when, decline, coal, start, it, started, natu...
# 2  [hillary, clinton, agrees, john, mccain, votin...
#
#                                           text_token  label_one_hot
# 0  [51, 8621, 1107, 1291, 683, 1823, 1523, 5606, ...              0
# 1  [1053, 2050, 1179, 619, 110, 232, 457, 114, 24...              1
# 2  [107, 389, 3557, 546, 441, 302, 500, 881, 584,...              1
